# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 5.3 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 7.4 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 optuna-3.5.0

# %%
import pandas as pd
import numpy as np
import datetime
from tqdm.notebook import tqdm
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import requests
from bs4 import BeautifulSoup
import time
import re
from urllib.request import urlopen
import optuna.integration.lightgbm as lgb_o
from itertools import combinations, permutations
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class Results:
    @staticmethod
    def scrape(race_id_list):
        """
        レース結果データをスクレイピングする関数
        Parameters:
        ----------
        race_id_list : list
            レースIDのリスト
        Returns:
        ----------
        race_results_df : pandas.DataFrame
            全レース結果データをまとめてDataFrame型にしたもの
        """
        #race_idをkeyにしてDataFrame型を格納
        race_results = {}
        for race_id in tqdm(race_id_list):
            time.sleep(1)
            try:
                url = "https://db.netkeiba.com/race/" + race_id
                # スクレイピング
                html = requests.get(url)
                html.encoding = "EUC-JP"
                # メインとなるテーブルデータを取得
                df = pd.read_html(html.text)[0]
                # 列名に半角スペースがあれば除去する
                df = df.rename(columns=lambda x: x.replace(' ', ''))
                # 天候、レースの種類、コースの長さ、馬場の状態、日付をスクレイピング
                soup = BeautifulSoup(html.text, "html.parser")
                texts = (
                    soup.find("div", attrs={"class": "data_intro"}).find_all("p")[0].text
                    + soup.find("div", attrs={"class": "data_intro"}).find_all("p")[1].text
                )
                info = re.findall(r'\w+', texts)
                for text in info:
                    if text in ["芝", "ダート"]:
                        df["race_type"] = [text] * len(df)
                    if "障" in text:
                        df["race_type"] = ["障害"] * len(df)
                    if "m" in text:
                        df["course_len"] = [int(re.findall(r"\d+", text)[-1])] * len(df)
                    if text in ["良", "稍重", "重", "不良"]:
                        df["ground_state"] = [text] * len(df)
                    if text in ["曇", "晴", "雨", "小雨", "小雪", "雪"]:
                        df["weather"] = [text] * len(df)
                    if "年" in text:
                        df["date"] = [text] * len(df)
                #馬ID、騎手IDをスクレイピング
                horse_id_list = []
                horse_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/horse")}
                )
                for a in horse_a_list:
                    horse_id = re.findall(r"\d+", a["href"])
                    horse_id_list.append(horse_id[0])
                jockey_id_list = []
                jockey_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/jockey")}
                )
                for a in jockey_a_list:
                    jockey_id = re.findall(r"\d+", a["href"])
                    jockey_id_list.append(jockey_id[0])
                df["horse_id"] = horse_id_list
                df["jockey_id"] = jockey_id_list
                #インデックスをrace_idにする
                df.index = [race_id] * len(df)
                race_results[race_id] = df
            #存在しないrace_idを飛ばす
            except IndexError:
                continue
            except AttributeError: #存在しないrace_idでAttributeErrorになるページもあるので追加
                continue
            #wifiの接続が切れた時などでも途中までのデータを返せるようにする
            except Exception as e:
                print(e)
                break
            #Jupyterで停止ボタンを押した時の対処
            except:
                break
        #pd.DataFrame型にして一つのデータにまとめる
        race_results_df = pd.concat([race_results[key] for key in race_results])
        return race_results_df

# %%
#馬の過去成績データを処理するクラス
class HorseResults:
    @staticmethod
    def scrape(horse_id_list):
        """
        馬の過去成績データをスクレイピングする関数

        Parameters:
        ----------
        horse_id_list : list
            馬IDのリスト

        Returns:
        ----------
        horse_results_df : pandas.DataFrame
            全馬の過去成績データをまとめてDataFrame型にしたもの
        """

        #horse_idをkeyにしてDataFrame型を格納
        horse_results = {}
        for horse_id in tqdm(horse_id_list):
            time.sleep(1)
            try:
                url = 'https://db.netkeiba.com/horse/' + horse_id
                df = pd.read_html(url)[3]
                #受賞歴がある馬の場合、3番目に受賞歴テーブルが来るため、4番目のデータを取得する
                if df.columns[0]=='受賞歴':
                    df = pd.read_html(url)[4]
                df.index = [horse_id] * len(df)
                horse_results[horse_id] = df
            except IndexError:
                continue
            except Exception as e:
                print(e)
                break
            except:
                break

        #pd.DataFrame型にして一つのデータにまとめる
        horse_results_df = pd.concat([horse_results[key] for key in horse_results])

        return horse_results_df

# %%
race_id_list = []
for place in range(1, 11, 1):
    for kai in range(1, 7, 1):
        for day in range(1, 13, 1):
            for r in range(1, 13, 1):
                race_id = "2019" + str(place).zfill(2) + str(kai).zfill(2) + str(day).zfill(2) + str(r).zfill(2)
                race_id_list.append(race_id)

# %%
race_id_list=["202206050911"]
results = Results.scrape(race_id_list)
results.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#               着順  枠番  馬番         馬名  性齢  斤量    騎手     タイム     着差    単勝  人気  \
# 202206050911   1   6  11    ドゥラエレーデ  牡2  55  ムルザバ  2:01.5    NaN  90.6  14
# 202206050911   2   4   8     トップナイフ  牡2  55  横山典弘  2:01.5     ハナ  18.7   7
# 202206050911   3   7  15    キングズレイン  牡2  55  ルメール  2:01.7  1.1/4  18.2   6
# 202206050911   4   1   1   ファントムシーフ  牡2  55  福永祐一  2:01.7     クビ   5.1   2
# 202206050911   5   8  18  ミッキーカプチーノ  牡2  55  戸崎圭太  2:01.8    1/2   3.0   1
#
#                    馬体重       調教師  course_len weather race_type ground_state  \
# 202206050911   508(+4)   [西] 池添学        2000       晴         芝            良
# 202206050911   494(+4)    [西] 昆貢        2000       晴         芝            良
# 202206050911   484(+4)  [東] 手塚貴久        2000       晴         芝            良
# 202206050911  502(+10)  [西] 西村真幸        2000       晴         芝            良
# 202206050911   524(+2)  [西] 矢作芳人        2000       晴         芝            良
#
#                      date    horse_id jockey_id
# 202206050911  2022年12月28日  2020103626     05627
# 202206050911  2022年12月28日  2020106402     00660
# 202206050911  2022年12月28日  2020103466     05339
# 202206050911  2022年12月28日  2020106582     01014
# 202206050911  2022年12月28日  2020104484     05386

# %%
horse_id_list = results['horse_id'].unique()
horse_results = HorseResults.scrape(horse_id_list)
horse_results #jupyterで出力

# %%
#日付をdatetime型へ変換
horse_results["日付"] = pd.to_datetime(horse_results["日付"], format='%Y/%m/%d')
horse_results = horse_results[horse_results["日付"] < datetime.datetime(2022,12,28)]
horse_results
# Out:
#                    日付     開催 天 気     R            レース名  映 像  頭 数  枠 番  馬 番  \
# 2020103626 2022-11-19   5東京5   晴  11.0  東京スポーツ杯2歳S(G2)  NaN   11  6.0    7
# 2020103626 2022-08-20   2札幌3   曇   2.0           2歳未勝利  NaN   12  6.0    7
# 2020103626 2022-08-06   1札幌5   曇   1.0           2歳未勝利  NaN   10  1.0    1
# 2020103626 2022-06-26   3阪神4   晴   5.0            2歳新馬  NaN   12  5.0    5
# 2020106402 2022-11-26   5阪神7   晴  11.0  ラジオN杯京都2歳S(G3)  NaN   15  3.0    4
# 2020106402 2022-10-29   4阪神8   晴   9.0           萩S(L)  NaN    7  3.0    3
# 2020106402 2022-09-24   5中京6   晴   9.0        野路菊S(OP)  NaN    7  2.0    2
# 2020106402 2022-09-04   2札幌8   晴   1.0           2歳未勝利  NaN    8  1.0    1
# 2020106402 2022-08-13   2札幌1   晴   1.0           2歳未勝利  NaN   12  3.0    3
# 2020106402 2022-07-24   1札幌2   曇   5.0            2歳新馬  NaN    9  6.0    6
# 2020103466 2022-11-06   5東京2   晴   9.0    百日草特別(1勝クラス)  NaN    9  2.0    2
# 2020103466 2022-08-27   2札幌5   曇   1.0           2歳未勝利  NaN    7  5.0    5
# 2020103466 2022-07-17  1函館12   雨   5.0            2歳新馬  NaN   11  3.0    3
# 2020106582 2022-09-24   5中京6   晴   9.0        野路菊S(OP)  NaN    7  1.0    1
# 2020106582 2022-06-18   3阪神1   曇   5.0            2歳新馬  NaN   12  8.0   12
# 2020104484 2022-12-03   5中山1   曇   9.0     葉牡丹賞(1勝クラス)  NaN   18  3.0    5
# 2020104484 2022-10-09   4東京2   曇   5.0            2歳新馬  NaN   15  1.0    1
# 2020103521 2022-11-13   5阪神4   曇   9.0      黄菊賞(1勝クラス)  NaN    9  8.0    8
# 2020103521 2022-10-02   4中山9   晴   5.0            2歳新馬  NaN   14  6.0   10
# 2020105681 2022-11-19   5東京5   晴  11.0  東京スポーツ杯2歳S(G2)  NaN   11  7.0    8
# 2020105681 2022-09-18   5中京4   晴   5.0            2歳新馬  NaN   11  7.0    8
# 2020103420 2022-11-12   5阪神3   晴   3.0           2歳未勝利  NaN   11  8.0   10
# 2020103420 2022-10-10   4阪神3   曇   5.0            2歳新馬  NaN    9  3.0    3
# 2020101695 2022-10-01   4中山8   晴   9.0         芙蓉S(OP)  NaN    7  4.0    4
# 2020103876   23.9  ...  1.0     **     8-9-10  38.2-35.3  34.3    490(0)
# 2020105730  216.1  ...  1.3     **  6-7-12-12  36.6-35.6  35.6  462(+12)
# 2020105730   58.0  ...  1.9     **    7-7-7-7  36.3-33.8  34.8   450(-4)
# 2020105730    6.4  ... -0.5     **    8-8-2-1  36.5-35.4  35.3    454(0)
#
#            厩舎 ｺﾒﾝﾄ  備考    勝ち馬 (2着馬)      賞金
# 2020103626     NaN NaN       ガストリック   570.0
# 2020103626     NaN NaN    (シゲルカミカゼ)   520.0
# 2020103626     NaN NaN         ドゥーラ   210.0
# 2020103626     NaN NaN    カルロヴェローチェ    70.0
# 2020106402     NaN NaN    グリューネグリーン  1315.2
# 2020106402     NaN NaN   (ナイトキャッスル)  1715.4
# 2020106402     NaN NaN     ファントムシーフ   240.0
# 2020106402     NaN NaN    (エルデストサン)   520.0
# 2020106402     NaN NaN     トーセンウォルト   130.0
# 2020106402     NaN NaN        ドゥアイズ     NaN
# 2020103466     NaN NaN   (ロードプレイヤー)  1049.6
# 2020103466     NaN NaN    (トーセントラム)   520.0
# 2020103466     NaN NaN     キミノナハマリア   180.0
# 2020106582     NaN NaN    (アリスヴェリテ)  1614.7
# 2020106582     NaN NaN    (ピヌスアモリス)   700.0
# 2020104484     NaN NaN    (ビターグラッセ)  1069.9
# 2020104484     NaN NaN   (フリームファクシ)   700.0
# 2020103521     NaN NaN   (ビューティーワン)  1049.6
# 2020103521     NaN NaN  (トーセンアウローラ)   700.0
# 2020105681     NaN NaN       ガストリック   955.5
# 2020105681     NaN NaN   (アルナージェイン)   700.0
# 2020103420     NaN NaN  (ファームツエンティ)   520.0
# 2020103420     NaN NaN      グランヴィノス   280.0
# 2020101695     NaN NaN  (ゴールデンハインド)  1614.7
# 2020101695     NaN NaN       キタウイング   785.5
# 2020101695     NaN NaN   (ルクスグローリア)   700.0
# 2020103331     NaN NaN  (モルトヴェローチェ)   700.0
# 2020102194     NaN NaN     (トップナイフ)  3353.2
# 2020102194     NaN NaN   (フライウィズミー)   520.0
# 2020102194     NaN NaN    ミッキーカプチーノ   180.0
# 2020103060     NaN NaN    グリューネグリーン   837.6
# 2020103060     NaN NaN   (モズマーカッシン)   520.0
# 2020103060     NaN NaN      バルサムノート   280.0
# 2020106439     NaN NaN  (トーセンエスクード)   700.0
# 2020103208     NaN NaN         (セオ)   520.0
# 2020103208     NaN NaN      インスタキング   280.0
# 2020103388     NaN NaN       ガストリック   380.0
# 2020103388     NaN NaN        (ノエマ)   700.0
# 2020106274     NaN NaN   (ダノンザタイガー)  3838.5
# 2020106274     NaN NaN      (ダニーデン)   700.0
# 2020103876     NaN NaN    (エルデストサン)   750.0
# 2020103876     NaN NaN          トレド   414.8
# 2020103876     NaN NaN   (ツインクルトーズ)   520.0
# 2020103876     NaN NaN     ウインオーディン     NaN
# 2020103876     NaN NaN    シルヴァーデューク   210.0
# 2020103876     NaN NaN     オンザブロッサム    70.0
# 2020105730     NaN NaN        レミージュ     NaN
# 2020105730     NaN NaN     ファントムシーフ     NaN
# 2020105730     NaN NaN  (インクルードダイヤ)   700.0
#
# [49 rows x 28 columns]
# Warning: Total number of columns (28) exceeds max_columns (20) limiting to first (20) columns.
